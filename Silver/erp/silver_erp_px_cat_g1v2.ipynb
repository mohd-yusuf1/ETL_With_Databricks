# %% [markdown]
# ## Read from bronze

# %%
df = spark.table("workspace.bronze.erp_px_cat_g1v2")
df.display()

# %% [markdown]
# ### This table dont need to any transformation load directly into silver layer

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.silver.erp_px_cat_g1v2")

# %%
display(spark.table("workspace.silver.erp_px_cat_g1v2"))
