# %% [markdown]
# ## Read from bronze

# %%
df = spark.table("workspace.bronze.erp_cust_az12")
df.display()

# %% [markdown]
# ### Normalize and trim the data

# %%
query = """
    SELECT
        CASE 
            WHEN CID LIKE "NAS%" THEN SUBSTRING(CID,4,LENGTH(CID))
            ELSE CID
        END CID,
        BDATE,
        CASE 
            WHEN UPPER(TRIM(GEN)) IN('M', 'MALE') THEN 'Male'
            WHEN UPPER(TRIM(GEN)) IN('F', 'FEMALE') THEN 'Female'
            ELSE 'n/a'
        END GEN
    FROM workspace.bronze.erp_cust_az12;
"""

df = spark.sql(query)
df.display()

# %% [markdown]
# ## Load into silver layer

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.silver.erp_cust_az12")

# %%
display(spark.table("workspace.silver.erp_cust_az12"))
